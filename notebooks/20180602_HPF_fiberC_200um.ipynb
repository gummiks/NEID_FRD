# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import datetime
import matplotlib.dates as mdates

# ---------- Graphics ------------
import seaborn as sns; sns.set()
sns.set_context("poster",font_scale=1.2,rc={"font":"helvetica"});
sns.set_style("white"); #sns.set_style("ticks")
cp = sns.color_palette("colorblind") #sns.palplot(current_palette)
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["savefig.dpi"] = 100
rcParams['mathtext.fontset'] = 'stix'
rcParams['font.family'] = 'STIXGeneral'
rcParams['font.weight'] = "normal"
rcParams["axes.formatter.useoffset"] = False
rcParams['xtick.major.width']=1
rcParams['xtick.major.size']=4
rcParams['xtick.minor.width']=0.5
rcParams['xtick.minor.size']=2
rcParams['xtick.direction'] = "in"
rcParams['ytick.direction'] = "in"
rcParams['ytick.major.width']=1
rcParams['ytick.major.size']=4
rcParams['ytick.minor.width']=0.5
rcParams['ytick.minor.size']=2
# ---------- Graphics ------------

import glob
import sys
sys.path.append("../src/")
try:
    sys.path.remove('/Users/gks/Dropbox/mypylib')
    sys.path.remove('/Users/gks/Dropbox/mypylib/GIT')
except Exception as e:
    print('Already removed')
    
#### Import frd packages
import utils
import phothelp
from frdimg import FRDImg, AnalyzeFRDImages
from frdimg_help import add_y_in_input, resample_df_mean, resample_df_mean, get_EE_from_rad_in_pix
# Out:
# Already removed

# %% [markdown]
# #### Setting up data

# %%
# Folders
BASEFOLDER       = "/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/"
FOLDER_CSV_SETUP = BASEFOLDER+"ANALYSIS/CSV_SETUP/"
FOLDER_CSV_SAVE  = BASEFOLDER+"ANALYSIS/CSV_RESULTS/"
PLOT_FOLDER      = BASEFOLDER+"ANALYSIS/PLOTS/"

# Files
setup_csv_files  = sorted(glob.glob(FOLDER_CSV_SETUP+"*.csv"))
fitsfiles_f01    = glob.glob(BASEFOLDER+"f01/*.fits")
fitsfiles_f02    = glob.glob(BASEFOLDER+"f02/*.fits")
#fitsfiles_f03    = glob.glob(BASEFOLDER+"f03/*.fits")
#fitsfiles_f04    = glob.glob(BASEFOLDER+"f04/*.fits")
#fitsfiles_f05    = glob.glob(BASEFOLDER+"f05/*.fits")
#fitsfiles_f06    = glob.glob(BASEFOLDER+"f06/*.fits")
#fitsfiles_f07    = glob.glob(BASEFOLDER+"f07/*.fits")
#fitsfiles_f08    = glob.glob(BASEFOLDER+"f08/*.fits")
#fitsfiles_f09    = glob.glob(BASEFOLDER+"f09/*.fits")
#fitsfiles_f10    = glob.glob(BASEFOLDER+"f10/*.fits")

# %%
# Checking setup files, we currently are only using file #1
setup_csv_files
# Out:
# ['/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/CSV_SETUP/setup_f01.csv',
#  '/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/CSV_SETUP/setup_f02.csv',
#  '/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/CSV_SETUP/setup_f03.csv',
#  '/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/CSV_SETUP/setup_f04.csv']

# %%
import matplotlib.pyplot as plt
plt.switch_backend("agg")
fig, ax= plt.subplots()

# %%
##########################
# MAIN analysis step
AFRDImg = AnalyzeFRDImages(fitsfiles=sorted(fitsfiles_f01),
                           plot_suffix="f01",
                           plot_folder=PLOT_FOLDER,
                           setup_csv_file=setup_csv_files[0],
                           FOLDER_CSV_SAVE=FOLDER_CSV_SAVE,
                           motorized=True,
                           MAXRAD_FACTOR=0.56,
                           fwzm_z=200.,
                           use_azimuthal_averaging=True)
AFRDImg.analyze_all_frames()
##########################
# Out:
# /Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/CSV_RESULTS/ already exists. Skipping
# Trimming problematic first row !
# ('Analyzing file #', 0, '/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/f01/f_psm_01_d_01.fits')
# /Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/PLOTS/ already exists. Skipping
# ('Centroids', 516.0806642238252, 481.20717915047305)
# Subtracted min value: -257.3888830452811
# Using azimuthal averaging
# Calculating radial data
# Calculating radial data using centroid: 516.2443102271891 481.29142773126887
# Subtracting min value from azimuthal average 258.81660144571157
# HWZM [386.19887068]
# ('Saved file:', '/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/PLOTS/f_psm_01_d_01.fits_f01.png')
# ('Saved file:', '/Users/gks/Dropbox/mypylib/data/NEID_FRD/20180602_HPF_fiberC_200um/ANALYSIS/PLOTS/f_psm_01_d_01.fits_f01.csv')
# ('Radii at EE:', 307.2273354875425)
# ...

# %% [markdown]
# # Now restart the notebook, and then rerun everything except main Analysis step above
# This is to make the following step a bit faster, as currently AFRDImg is a bit slow if it has run the full pipeline step

# %%
# Create a clean instance of AFRDImg to make the following code quicker to run
AFRDImg = AnalyzeFRDImages(fitsfiles=sorted(fitsfiles_f01),
                           plot_suffix="f01",
                           plot_folder=PLOT_FOLDER,
                           setup_csv_file=setup_csv_files[0],
                           FOLDER_CSV_SAVE=FOLDER_CSV_SAVE,
                           motorized=True,
                           MAXRAD_FACTOR=0.56,
                           fwzm_z=200.)
# Make plots inline
# %matplotlib inline

# Find  .csv files
list_of_df_config = sorted(glob.glob(FOLDER_CSV_SAVE+"*.csv"))

df_config_f01 = pd.read_csv(list_of_df_config[0])
#df_config_f02 = pd.read_csv(list_of_df_config[1])
#df_config_f03 = pd.read_csv(list_of_df_config[2])

df_config_f01 = add_y_in_input(df_config_f01)
#df_config_f02 = add_y_in_input(df_config_f02)
#df_config_f03 = add_y_in_input(df_config_f03)

df_config_f01 = AFRDImg._get_EE_in_input_cone(df_config_f01,suffix="f01")
#df_config_f02 = AFRDImg._get_EE_in_input_cone(df_config_f02,suffix="f02")
#df_config_f03 = AFRDImg._get_EE_in_input_cone(df_config_f03,suffix="f03")

df_config_f01_res = resample_df_mean(df_config_f01)
#df_config_f02_res = resample_df_mean(df_config_f02)
#df_config_f03_res = resample_df_mean(df_config_f03)

resample_array = [2.5,3.33,3.5,3.65,4.,5.,6.,7.]
resample_array = [2.5,2.73,3.,3.33,3.5,3.65,3.75,4.,4.62,5.,6.,6.67,7.]

df_int_f01 = utils.resample_df(df_config_f01_res,resample_array,"f_ratio_in")
#df_int_f02 = gkastro.resample_df(df_config_f02_res,resample_array,"f_ratio_in")
#df_int_f03 = gkastro.resample_df(df_config_f03_res,resample_array,"f_ratio_in")
# Out:
# 0
# f_psm_01_d_01.fits
# Skip!
# 1
# f_psm_01_d_02.fits
# ('Rad_in_pix', 357.4525358887974)
# ('Now getting EE from rad in pix', 0.9835619386842831)
# 2
# f_psm_01_d_03.fits
# /Users/gks/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# ('Rad_in_pix', 359.13057686554794)
# ('Now getting EE from rad in pix', 0.9768170571879875)
# 3
# f_psm_01_d_04.fits
# ('Rad_in_pix', 362.60760136336177)
# ('Now getting EE from rad in pix', 0.9682198938864803)
# 4
# f_psm_02_d_01.fits
# Skip!
# 5
# f_psm_02_d_02.fits
# ('Rad_in_pix', 329.100976160848)
# ('Now getting EE from rad in pix', 0.9798098617748378)
# 6
# f_psm_02_d_03.fits
# ('Rad_in_pix', 352.05746399702804)
# ...

# %% [markdown]
# # Main plot

# %%
PLOT_TITLE = "20180602_HPF_fiberC_200um"
PLOT_TITLE
# New
fig, ax = plt.subplots(ncols=2,figsize=(18,7))
fig.suptitle(PLOT_TITLE,fontsize=32)
ax.flat[0].plot(df_int_f01.f_ratio_in,df_int_f01.EE_in_input_cone,label="Oct Fiber",color=cp[0],alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_int_f02.f_ratio_in,df_int_f02.EE_in_input_cone,label="Recoat",color=cp[1],alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_int_f03.f_ratio_in,df_int_f03.EE_in_input_cone,label="Fiber #3",color=cp[2],alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_int_f04.f_ratio_in,df_int_f04.EE_in_input_cone,label="Fiber #o4",color=cp[3],alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_int_f09.f_ratio_in,df_int_f09.EE_in_input_cone,label="Fiber #c5",color=cp[4],alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_int_f10.f_ratio_in,df_int_f10.EE_in_input_cone,label="Fiber #c6",color=cp[5],alpha=0.8,lw=1,marker="o",markersize=5)

ax.flat[0].minorticks_on()
ax.flat[0].set_xlabel("Input F/#")
ax.flat[0].set_ylabel("Output EE within input F/#")
ax.flat[0].grid(lw=0.5,alpha=0.3)
#ax.flat[0].set_title(PLOT_TITLE,y=1.02)
ax.flat[0].set_ylim(*ax.flat[0].get_ybound())
ax.flat[0].vlines(3.65,*ax.flat[0].get_ybound(),color="orange",alpha=0.5,linestyle="--",linewidth=1,label="F/# = 3.65")
ax.flat[0].legend(loc="lower left",fontsize=12)
ax.flat[0].margins(x=0.05)

#fig, ax = plt.subplots()
ax.flat[1].plot(df_config_f01_res.f_ratio_in,df_config_f01_res.f_ratio_out,color=cp[0],label="Oct Fiber, EE96",alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_config_f02_res.f_ratio_in,df_config_f02_res.f_ratio_out,color=cp[1],label="Recoat, EE96",alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_config_f03_res.f_ratio_in,df_config_f03_res.f_ratio_out,color=cp[2],label="Fiber #o3, EE96",alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_config_f04_res.f_ratio_in,df_config_f04_res.f_ratio_out,color=cp[3],label="Fiber #o4, EE96",alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_config_f09_res.f_ratio_in,df_config_f09_res.f_ratio_out,color=cp[4],label="Fiber #c5, EE96",alpha=0.8,lw=1,marker="o",markersize=5)
#ax.plot(df_config_f10_res.f_ratio_in,df_config_f10_res.f_ratio_out,color=cp[5],label="Fiber #c6, EE96",alpha=0.8,lw=1,marker="o",markersize=5)

ax.flat[1].set_xlabel("Input F/#")
ax.flat[1].set_ylabel("Output F/#")
#ax.flat[1].set_title(PLOT_TITLE,y=1.01)
ax.flat[1].minorticks_on()
xx = np.linspace(1.6,8,100)
ax.flat[1].plot(xx,xx,color="black",alpha=0.4,lw=1,ls="--")
ax.flat[1].grid(lw=0.5,alpha=0.3)
ax.flat[1].vlines(3.65,*ax.flat[1].get_ybound(),color="orange",alpha=0.5,linestyle="--",linewidth=1,label="F/# = 3.65")
ax.flat[1].legend(loc="upper left",fontsize=14)
#ax.set_ylim(2.,4.)
#ax.set_xlim(2.,6.)
ax.flat[1].scatter(df_config_f01.f_ratio_in,df_config_f01.f_ratio_out,color=cp[0],alpha=0.8,s=10,marker="1")
#ax.scatter(df_config_f02.f_ratio_in,df_config_f02.f_ratio_out,color=cp[1],alpha=0.8,s=10,marker="1")
#ax.scatter(df_config_f03.f_ratio_in,df_config_f03.f_ratio_out,color=cp[2],alpha=0.8,s=10,marker="1")
#ax.scatter(df_config_f04.f_ratio_in,df_config_f04.f_ratio_out,color=cp[3],alpha=0.8,s=10,marker="1")
#ax.set_ylim(2.4,4.2)
#ax.scatter(df_config_f09.f_ratio_in,df_config_f09.f_ratio_out,color=cp[4],alpha=0.3,s=10,marker="1")
